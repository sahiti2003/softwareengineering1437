# %%
import matplotlib.pyplot as plt
import numpy as np
a = 0.01
b = -0.2
c = 20
days = np.arange(1, 50, 1)
temperature_model = lambda x: a * x**2 + b * x + c
temperatures = temperature_model(days)
plt.plot(days, temperatures, label='Temperature Model')
plt.xlabel('Days')
plt.ylabel('Temperature (°C)')
plt.title('Quadratic Weather Modeling')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
a = float(input("enter a values: "))
b = float(input("enter b values: "))
c = float(input("enter c values: "))
days = np.arange(1, 50, 1)
temperature_model = lambda x: a * x**2 + b * x + c
temperatures = temperature_model(days)
plt.plot(days, temperatures, label='Temperature Model')
plt.xlabel('Days')
plt.ylabel('Temperature (°C)')
plt.title('Quadratic Weather Modeling')
plt.legend()
plt.show()
# Out:
# enter a values: 0.01
# enter b values: -0.5
# enter c values: 20

# %%
import matplotlib.pyplot as plt
import numpy as np

def quadratic(time, a, b, c):
    temp = a * time**2 + b * time + c
    return temp

with open("file.txt", 'r') as f:
    coefficients = [float(value) for value in f.read().strip().split()]

a, b, c = coefficients

time = np.arange(0, 50, 1)
plt.plot(time, quadratic(time, a, b, c), label=f'file input: a={a}, b={b}, c={c}')
plt.xlabel("TEMPERATURE")
plt.ylabel("TIME")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as p
import numpy as np
def quadratic(time,a,b,c):
  temp=a*time**2+b*time+cS
  return temp
a1=0.01
b1=-0.3
c1=40
time=np.arange(0,50,1)
p.plot(time,quadratic(time,a1,b1,c1),label='hard code')
a=float(input("Enter a value: "))
b=float(input("Enter b value: "))
c=float(input("Enter c value: "))

p.plot(time,quadratic(time,a,b,c),label='user input')
p.xlabel("TEMPERATURE")
p.ylabel("TIME")
p.legend()
p.show()
# Out:
# Enter a value: 0.04
# Enter b value: -0.4
# Enter c value: 40

# %%
import matplotlib.pyplot as plt
import numpy as np

def quadratic_solution(a, b, c, x):
    """
    Calculate the quadratic solution for the given coefficients and x value.
    """
    y = a * x**2 + b * x + c
    return y

def plot_temperature_over_time(a, b, c, time_range):
    """
    Plot temperature over time using a quadratic function.
    """
    time = np.array(time_range)
    temperature = quadratic_solution(a, b, c, time)

    plt.plot(time, temperature, label=f'a={a}, b={b}, c={c}')

def main():
    print("Weather Modeling using Quadratic Solution")

    # Get the number of sets
    num_sets = int(input("Enter the number of sets: "))

    for _ in range(num_sets):
        # Input coefficients for each set
        a = float(input("Enter the value of a: "))
        b = float(input("Enter the value of b: "))
        c = float(input("Enter the value of c: "))

        # Hard-coded time values
        time_range = np.linspace(0, 10, 100)  # Adjust the time range as needed

        # Plot temperature over time using the quadratic function for each set
        plot_temperature_over_time(a, b, c, time_range)

    # Show the legend and display the plot
    plt.legend()
    plt.title("Temperature Over Time for Multiple Sets")
    plt.xlabel("Time")
    plt.ylabel("Temperature")
    plt.grid(True)
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Weather Modeling using Quadratic Solution
# Enter the number of sets: 3
# Enter the value of a: 0.01
# Enter the value of b: -0.5
# Enter the value of c: 20
# Enter the value of a: 0.04
# Enter the value of b: -0.7
# Enter the value of c: 40
# Enter the value of a: 0.06
# Enter the value of b: -0.1
# Enter the value of c: 70
